# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
xtrain=pd.read_table('/Users/sinchana/Desktop/Human-Activity-Recognition-using-machine-learning-master/human+activity+recognition+using+smartphones 2/UCI HAR Dataset/train/X_train.txt',delim_whitespace=True,header=None)

# %%
xtest=pd.read_table('/Users/sinchana/Desktop/Human-Activity-Recognition-using-machine-learning-master/human+activity+recognition+using+smartphones 2/UCI HAR Dataset/test/X_test.txt',delim_whitespace=True,header=None)

# %%
ytrain=pd.read_table('/Users/sinchana/Desktop/Human-Activity-Recognition-using-machine-learning-master/human+activity+recognition+using+smartphones 2/UCI HAR Dataset/train/y_train.txt',header=None)

# %%
ytest=pd.read_table('/Users/sinchana/Desktop/Human-Activity-Recognition-using-machine-learning-master/human+activity+recognition+using+smartphones 2/UCI HAR Dataset/test/y_test.txt',header=None)

# %%
xtrain.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.288585 -0.020294 -0.132905 -0.995279 -0.983111 -0.913526 -0.995112
# 1  0.278419 -0.016411 -0.123520 -0.998245 -0.975300 -0.960322 -0.998807
# 2  0.279653 -0.019467 -0.113462 -0.995380 -0.967187 -0.978944 -0.996520
# 3  0.279174 -0.026201 -0.123283 -0.996091 -0.983403 -0.990675 -0.997099
# 4  0.276629 -0.016570 -0.115362 -0.998139 -0.980817 -0.990482 -0.998321
#
#         7         8         9    ...       551       552       553       554  \
# 0 -0.983185 -0.923527 -0.934724  ... -0.074323 -0.298676 -0.710304 -0.112754
# 1 -0.974914 -0.957686 -0.943068  ...  0.158075 -0.595051 -0.861499  0.053477
# 2 -0.963668 -0.977469 -0.938692  ...  0.414503 -0.390748 -0.760104 -0.118559
# 3 -0.982750 -0.989302 -0.938692  ...  0.404573 -0.117290 -0.482845 -0.036788
# 4 -0.979672 -0.990441 -0.942469  ...  0.087753 -0.351471 -0.699205  0.123320
#
#         555       556       557       558       559       560
# 0  0.030400 -0.464761 -0.018446 -0.841247  0.179941 -0.058627
# 1 -0.007435 -0.732626  0.703511 -0.844788  0.180289 -0.054317
# 2  0.177899  0.100699  0.808529 -0.848933  0.180637 -0.049118
# 3 -0.012892  0.640011 -0.485366 -0.848649  0.181935 -0.047663
# 4  0.122542  0.693578 -0.615971 -0.847865  0.185151 -0.043892
#
# [5 rows x 561 columns]

# %%
classifier = RandomForestClassifier()

# %%
parameters = {'n_estimators': [10, 100, 1000], 'max_depth': [3, 6, 9], 'max_features' : ['auto', 'log2']}

# %%
model=GridSearchCV(classifier,parameters,n_jobs=-1,cv=4,scoring='accuracy',verbose=4)
model.fit(xtrain.values,ytrain.values.ravel().T)
# Out:
# Fitting 4 folds for each of 18 candidates, totalling 72 fits
# /Users/sinchana/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:425: FitFailedWarning:
# 36 fits failed out of a total of 72.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 26 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/sinchana/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sinchana/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "/Users/sinchana/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/sinchana/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 10 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/sinchana/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/sinchana/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "/Users/sinchana/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 637, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/sinchana/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 95, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/sinchana/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:976: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan 0.81379217 0.8234494  0.82793798
#         nan        nan        nan 0.88030468 0.90818825 0.90505985
#         nan        nan        nan 0.89526659 0.92083787 0.92219804]
#   warnings.warn(
# GridSearchCV(cv=4, estimator=RandomForestClassifier(), n_jobs=-1,
#              param_grid={'max_depth': [3, 6, 9],
#                          'max_features': ['auto', 'log2'],
#                          'n_estimators': [10, 100, 1000]},
#              scoring='accuracy', verbose=4)

# %%
from sklearn.metrics import accuracy_score
ypred=model.predict(xtest)
accuracy=accuracy_score(ytest,ypred)

# %%
print ('Best Parameters: '+ str(model.best_params_))
print ('Accuracy Score: '+ str(accuracy*100) + ' %')
# Out:
# Best Parameters: {'max_depth': 9, 'max_features': 'log2', 'n_estimators': 1000}
# Accuracy Score: 92.70444519850696 %
# [CV 2/4] END max_depth=3, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/4] END max_depth=3, max_features=log2, n_estimators=10;, score=0.788 total time=   0.2s
# [CV 1/4] END max_depth=3, max_features=log2, n_estimators=1000;, score=0.808 total time=  13.4s
# [CV 1/4] END max_depth=9, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 4/4] END max_depth=9, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/4] END max_depth=9, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/4] END max_depth=9, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/4] END max_depth=9, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 2/4] END max_depth=9, max_features=log2, n_estimators=10;, score=0.882 total time=   0.3s
# [CV 2/4] END max_depth=9, max_features=log2, n_estimators=100;, score=0.910 total time=   3.1s
# [CV 1/4] END max_depth=9, max_features=log2, n_estimators=1000;, score=0.913 total time=  25.1s
# [CV 1/4] END max_depth=3, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/4] END max_depth=3, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 1/4] END max_depth=3, max_features=log2, n_estimators=10;, score=0.811 total time=   0.2s
# [CV 4/4] END max_depth=3, max_features=log2, n_estimators=1000;, score=0.888 total time=  13.4s
# [CV 2/4] END max_depth=9, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/4] END max_depth=9, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/4] END max_depth=9, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/4] END max_depth=9, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 1/4] END max_depth=9, max_features=log2, n_estimators=10;, score=0.891 total time=   0.3s
# [CV 1/4] END max_depth=9, max_features=log2, n_estimators=100;, score=0.910 total time=   3.4s
# [CV 4/4] END max_depth=9, max_features=log2, n_estimators=1000;, score=0.967 total time=  25.2s
# [CV 3/4] END max_depth=3, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/4] END max_depth=3, max_features=log2, n_estimators=100;, score=0.799 total time=   1.3s
# [CV 1/4] END max_depth=6, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/4] END max_depth=6, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/4] END max_depth=6, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 1/4] END max_depth=6, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/4] END max_depth=6, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/4] END max_depth=6, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 3/4] END max_depth=6, max_features=log2, n_estimators=10;, score=0.872 total time=   0.3s
# [CV 2/4] END max_depth=6, max_features=log2, n_estimators=100;, score=0.908 total time=   2.4s
# [CV 4/4] END max_depth=6, max_features=log2, n_estimators=1000;, score=0.954 total time=  23.6s
# [CV 3/4] END max_depth=3, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 2/4] END max_depth=3, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 3/4] END max_depth=3, max_features=log2, n_estimators=10;, score=0.787 total time=   0.2s
# [CV 2/4] END max_depth=3, max_features=log2, n_estimators=1000;, score=0.831 total time=  13.4s
# [CV 3/4] END max_depth=9, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/4] END max_depth=9, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 4/4] END max_depth=9, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 3/4] END max_depth=9, max_features=log2, n_estimators=10;, score=0.879 total time=   0.3s
# [CV 3/4] END max_depth=9, max_features=log2, n_estimators=100;, score=0.900 total time=   3.2s
# [CV 2/4] END max_depth=9, max_features=log2, n_estimators=1000;, score=0.911 total time=  25.2s
# [CV 4/4] END max_depth=3, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/4] END max_depth=3, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 4/4] END max_depth=3, max_features=log2, n_estimators=10;, score=0.868 total time=   0.2s
# [CV 3/4] END max_depth=3, max_features=log2, n_estimators=1000;, score=0.784 total time=  13.5s
# [CV 4/4] END max_depth=9, max_features=log2, n_estimators=10;, score=0.928 total time=   0.4s
# [CV 4/4] END max_depth=9, max_features=log2, n_estimators=100;, score=0.963 total time=   3.2s
# [CV 3/4] END max_depth=9, max_features=log2, n_estimators=1000;, score=0.898 total time=  25.2s
# [CV 2/4] END max_depth=3, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/4] END max_depth=3, max_features=log2, n_estimators=100;, score=0.885 total time=   1.4s
# [CV 4/4] END max_depth=6, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 4/4] END max_depth=6, max_features=log2, n_estimators=10;, score=0.930 total time=   0.3s
# [CV 3/4] END max_depth=6, max_features=log2, n_estimators=100;, score=0.875 total time=   2.4s
# [CV 2/4] END max_depth=6, max_features=log2, n_estimators=1000;, score=0.903 total time=  23.6s
# [CV 1/4] END max_depth=3, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 4/4] END max_depth=3, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 2/4] END max_depth=3, max_features=log2, n_estimators=100;, score=0.823 total time=   1.4s
# [CV 2/4] END max_depth=6, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 1/4] END max_depth=6, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 2/4] END max_depth=6, max_features=log2, n_estimators=10;, score=0.841 total time=   0.3s
# [CV 4/4] END max_depth=6, max_features=log2, n_estimators=100;, score=0.946 total time=   2.4s
# [CV 3/4] END max_depth=6, max_features=log2, n_estimators=1000;, score=0.874 total time=  23.6s
# [CV 4/4] END max_depth=3, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 3/4] END max_depth=3, max_features=log2, n_estimators=100;, score=0.786 total time=   1.4s
# [CV 4/4] END max_depth=6, max_features=auto, n_estimators=10;, score=nan total time=   0.0s
# [CV 3/4] END max_depth=6, max_features=auto, n_estimators=100;, score=nan total time=   0.0s
# [CV 2/4] END max_depth=6, max_features=auto, n_estimators=1000;, score=nan total time=   0.0s
# [CV 1/4] END max_depth=6, max_features=log2, n_estimators=10;, score=0.878 total time=   0.2s
# [CV 1/4] END max_depth=6, max_features=log2, n_estimators=100;, score=0.904 total time=   2.4s
# [CV 1/4] END max_depth=6, max_features=log2, n_estimators=1000;, score=0.890 total time=  23.6s
